# %%
from scipy import constants
1 / (constants.Planck * constants.speed_of_light * 1e2)
# Out:
# 5.0341165675427096e+22

# %%
constants.Planck * constants.speed_of_light * 100
# Out:
# 1.9864458571489285e-23

# %%
constants.hbar / (constants.Planck * constants.speed_of_light * 100)
# Out:
# 5.3088374588761455e-12

# %%
1 / constants.Boltzmann
# Out:
# 7.24297051603992e+22

# %%
1 / constants.elementary_charge
# Out:
# 6.241509074460763e+18

# %%
constants.physical_constants['Hartree energy']
# Out:
# (4.3597447222071e-18, 'J', 8.5e-30)

# %%
constants.hbar / 4.3597447222071e-18 * 1e15
# Out:
# 0.024188843265857192

# %%
(1 / (constants.Planck * constants.speed_of_light * 100) * constants.hbar) ** -1
# Out:
# 188365156730.8853

# %%
constants.hbar * 5.0341165675427096e+22 * 1e15
# Out:
# 5308.837458876145

# %%
(5308.837458876145 / 200) ** -1
# Out:
# 0.03767303134617706

# %%
5 * 1000 * 0.03767303134617706
# Out:
# 188.3651567308853

# %%
(0.01883651567308853 / 100) ** -1 * 1e-15
# Out:
# 5.3088374588761455e-12
